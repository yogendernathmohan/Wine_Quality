# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("Wine_Quality.csv")

# %%
data
# Out:
#    Fixed Acidity  Volatile Acidity  Citric Acid  Residual Sugar  Chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.6              0.72         0.25             2.2      0.078
# 5            7.2              0.78         0.00             2.8      0.090
# 6            7.7              0.98         0.52             3.3      0.098
# 7            8.4              0.33         0.58             2.9      0.082
# 8            8.6              0.48         0.08             3.2      0.088
# 9           11.3              0.88         0.00             2.6      0.098
#
#    Free Sulfur dioxide  Total Sulfur dioxide  Density    pH  Sulphates  \
# 0                   11                    34   0.9978  3.51       0.56
# 1                   25                    67   0.9968  3.20       0.68
# 2                   15                    54   0.9970  3.26       0.65
# 3                   17                    60   0.9980  3.16       0.58
# 4                   13                    36   0.9998  3.71       0.70
# 5                   27                    63   0.9990  3.40       0.63
# 6                   18                    59   0.8670  3.60       0.66
# 7                   21                    68   0.7650  3.23       0.76
# 8                   19                    38   0.9970  3.50       0.55
# 9                   25                    67   0.9968  3.20       0.68
#
#    Alcohol  Quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.6        6
# 5      9.5        5
# 6      9.3        6
# 7      9.8        6
# 8      9.6        5
# 9      9.8        5

# %%
data.head()
# Out:
#    Fixed Acidity  Volatile Acidity  Citric Acid  Residual Sugar  Chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.6              0.72         0.25             2.2      0.078
#
#    Free Sulfur dioxide  Total Sulfur dioxide  Density    pH  Sulphates  \
# 0                   11                    34   0.9978  3.51       0.56
# 1                   25                    67   0.9968  3.20       0.68
# 2                   15                    54   0.9970  3.26       0.65
# 3                   17                    60   0.9980  3.16       0.58
# 4                   13                    36   0.9998  3.71       0.70
#
#    Alcohol  Quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.6        6

# %%
X=data.drop('Quality', axis=1)
y=data['Quality']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.8,random_state=48)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error,r2_score
mse = mean_squared_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)
print(f'Mean Squared Error:{mse}')
print(f'R-squared:{r2}')
# Out:
# Mean Squared Error:0.7892290267591452
# R-squared:-2.3673771808390196

# %%
import matplotlib.pyplot as plt
plt.scatter(y_test, y_pred)
plt.xlabel("Actual Wine Quality")
plt.ylabel("Predicted Wine Quality")
plt.title("Actual Wine Quality vs. Predicted Wine Quality")
plt.show()
